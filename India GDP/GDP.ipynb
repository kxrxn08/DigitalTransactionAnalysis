# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# In this notebook we have analysed the GDP data where we considered the Data from 1961 to 2023 and draw usefull insights regarding the GDP's measures like per capita income,Growth rate and many more

# %%
df=pd.read_csv('India_GDP_Data.csv')

# %%
df.head()
# Out:
#    Year  GDP_In_Billion_USD  Per_Capita_in_USD  Percentage_Growth
# 0  2021             3173.40               2277                8.95
# 1  2020             2667.69               1933               -6.60
# 2  2019             2831.55               2072                3.74
# 3  2018             2702.93               1998                6.45
# 4  2017             2651.47               1981                6.80

# %%
df.sort_values('Year',ascending=True,inplace=True)
df
# Out:
#     Year  GDP_In_Billion_USD  Per_Capita_in_USD  Percentage_Growth
# 60  1961               39.23                 85                3.72
# 59  1962               42.16                 90                2.93
# 58  1963               48.42                101                5.99
# 57  1964               56.48                116                7.45
# 56  1965               59.55                119               -2.64
# ..   ...                 ...                ...                 ...
# 4   2017             2651.47               1981                6.80
# 3   2018             2702.93               1998                6.45
# 2   2019             2831.55               2072                3.74
# 1   2020             2667.69               1933               -6.60
# 0   2021             3173.40               2277                8.95
#
# [61 rows x 4 columns]

# %% [markdown]
# Indian GDP from the year 1961 to 2021

# %%
df.shape
# Out:
# (61, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 61 entries, 60 to 0
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                61 non-null     int64
#  1   GDP_In_Billion_USD  61 non-null     float64
#  2   Per_Capita_in_USD   61 non-null     int64
#  3   Percentage_Growth   61 non-null     float64
# dtypes: float64(2), int64(2)
# memory usage: 2.4 KB

# %%
df.isnull().sum()
# Out:
# Year                  0
# GDP_In_Billion_USD    0
# Per_Capita_in_USD     0
# Percentage_Growth     0
# dtype: int64

# %%
df.describe().T
# Out:
#                     count         mean         std      min      25%      50%
# Year                 61.0  1991.000000   17.752934  1961.00  1976.00  1991.00  \
# GDP_In_Billion_USD   61.0   709.889016  870.169692    39.23   102.72   296.04
# Per_Capita_in_USD    61.0   611.163934  618.757227    85.00   163.00   346.00
# Percentage_Growth    61.0     5.089344    3.282711    -6.60     3.74     5.71
#
#                         75%      max
# Year                2006.00  2021.00
# GDP_In_Billion_USD   940.26  3173.40
# Per_Capita_in_USD    807.00  2277.00
# Percentage_Growth      7.55     9.63

# %%
# GDP depends on both `year` and `Per capita` and increses as both increases.
# Likewise "Per Capita" depends on both `year` and `GDP`

# %% [markdown]
# Taking out the correlation between the different aspects of GDP

# %%
df.corr()
# Out:
#                         Year  GDP_In_Billion_USD  Per_Capita_in_USD
# Year                1.000000            0.851546           0.869831  \
# GDP_In_Billion_USD  0.851546            1.000000           0.998592
# Per_Capita_in_USD   0.869831            0.998592           1.000000
# Percentage_Growth   0.276549            0.154507           0.172981
#
#                     Percentage_Growth
# Year                          0.276549
# GDP_In_Billion_USD            0.154507
# Per_Capita_in_USD             0.172981
# Percentage_Growth             1.000000

# %%
df
# Out:
#     Year  GDP_In_Billion_USD  Per_Capita_in_USD  Percentage_Growth
# 60  1961               39.23                 85                3.72
# 59  1962               42.16                 90                2.93
# 58  1963               48.42                101                5.99
# 57  1964               56.48                116                7.45
# 56  1965               59.55                119               -2.64
# ..   ...                 ...                ...                 ...
# 4   2017             2651.47               1981                6.80
# 3   2018             2702.93               1998                6.45
# 2   2019             2831.55               2072                3.74
# 1   2020             2667.69               1933               -6.60
# 0   2021             3173.40               2277                8.95
#
# [61 rows x 4 columns]

# %% [markdown]
# LINE PLOT

# %%
plt.figure(figsize=(10,4))
plt.plot(df["Year"],df["GDP_In_Billion_USD"],color="orange")
plt.title('GDP over time',color='green',size=16,family='serif')
plt.xlabel('Year',color='green',size=12,family='serif')
plt.ylabel('GDP(in Billion USD',color='green',size=12,family='serif')
plt.show()

# %% [markdown]
# Here from the graph it's clear shows we have an exponential journey and Digital Transaction became the catalyst into it

# %%
# GDP over past 5 years
GDP_5=df.sort_values('Year',ascending=False).head().reset_index()
GDP_5[['Year','GDP_In_Billion_USD']]
# Out:
#    Year  GDP_In_Billion_USD
# 0  2021             3173.40
# 1  2020             2667.69
# 2  2019             2831.55
# 3  2018             2702.93
# 4  2017             2651.47

# %%
#Per Capita Plot
plt.figure(figsize=(10,4))
plt.plot(df['Year'],df['Per_Capita_in_USD'],'-b')
plt.title('Per Capita change over time',size=16,family='serif',color = "red")
plt.xlabel("Year",size=12,color='red')
plt.ylabel('Per Capita(in USD)',size=12,color='red')
plt.show()

# %% [markdown]
# Per capita : It's the national income divided by population size

# %% [markdown]
# As the GDP rises per capita clearly increases

# %%
GDP_5.columns
# Out:
# Index(['index', 'Year', 'GDP_In_Billion_USD', 'Per_Capita_in_USD',
#        'Percentage_Growth '],
#       dtype='object')

# %%
# Per Capita over past 5 years
GDP_5=df.sort_values('Year',ascending=False).head().reset_index()
GDP_5[['Year','Per_Capita_in_USD']]
# Out:
#    Year  Per_Capita_in_USD
# 0  2021               2277
# 1  2020               1933
# 2  2019               2072
# 3  2018               1998
# 4  2017               1981

# %% [markdown]
# From the above plot,`Per Capita` increases with increase in `Year`
#
# ---

# %%
# percentage growth plot
plt.figure(figsize=(10,4))
plt.plot(df["Year"],df["Percentage_Growth "],'-g')
plt.title('Percentage Growth over time',size=16,family='serif',color = "orange")
plt.xlabel('Year',size=12,color='orange')
plt.ylabel('Percentage Growth',size=12,color='orange')
plt.show()

# %% [markdown]
# We have the constant grwoth rate over the time well there are some great dips due to terrorism or COVID-19 pendaemic

# %%
# Percentage growth over past 5 years
GDP_5=df.sort_values('Year',ascending=False).head().reset_index()
GDP_5[['Year','Percentage_Growth ']]
# Out:
#    Year  Percentage_Growth
# 0  2021                8.95
# 1  2020               -6.60
# 2  2019                3.74
# 3  2018                6.45
# 4  2017                6.80

# %%
plt.figure(figsize=(17,4))


#GDP Plot
plt.subplot(1,3,1)
plt.plot(df["Year"],df["GDP_In_Billion_USD"],color="orange")
plt.title('Year vs GDP',color='green',size=16,family='serif')
plt.xlabel('Year',color='green',size=12,family='serif')
plt.ylabel('GDP(in Billion USD',color='green',size=12,family='serif')

#Per Capita Plot
plt.subplot(1,3,2)
plt.plot(df['Year'],df['Per_Capita_in_USD'],'-b')
plt.title('Year vs Per Capita',size=16,family='serif',color = "red")
plt.xlabel("Year",size=12,color='red')
plt.ylabel('Per Capita(in USD)',size=12,color='red')

# percentage growth plot
plt.subplot(1,3,3)
plt.plot(df["Year"],df["Percentage_Growth "],'-g')
plt.title('Year vs Percentage Growth',size=16,family='serif',color = "orange")
plt.xlabel('Year',size=12,color='orange')
plt.ylabel('Percentage Growth',size=12,color='orange')

plt.show()

# %%
df.corr()
# Out:
#                         Year  GDP_In_Billion_USD  Per_Capita_in_USD
# Year                1.000000            0.851546           0.869831  \
# GDP_In_Billion_USD  0.851546            1.000000           0.998592
# Per_Capita_in_USD   0.869831            0.998592           1.000000
# Percentage_Growth   0.276549            0.154507           0.172981
#
#                     Percentage_Growth
# Year                          0.276549
# GDP_In_Billion_USD            0.154507
# Per_Capita_in_USD             0.172981
# Percentage_Growth             1.000000

# %% [markdown]
# In the below graph we have plot a box graph and in this we have seen that the growth rate of India in least during the decade of 1960 to 1980 as serious incidents occured during that phase

# %%
plt.figure(figsize=(20,6))
plt.suptitle('BOX PLOT',size=16,color="k")

# Year
plt.subplot(1,4,1)
plt.boxplot(df['Year'])
plt.title('Year',size=16,family='serif',color = "green")

# GDP
plt.subplot(1,4,2)
plt.boxplot(df['GDP_In_Billion_USD'])
plt.title('GDP_In_Billion_USD',size=16,family='serif',color = "orange")

# Per Capita
plt.subplot(1,4,3)
plt.boxplot(df['Per_Capita_in_USD'])
plt.title('Per_Capita_in_USD',size=16,family='serif',color = "blue")

# Percentage Growth
plt.subplot(1,4,4)
plt.boxplot(df['Percentage_Growth '])
plt.title('Percentage_Growth ',size=16,family='serif',color = "green")

plt.show()

# %%
df.describe().T
# Out:
#                     count         mean         std      min      25%      50%
# Year                 61.0  1991.000000   17.752934  1961.00  1976.00  1991.00  \
# GDP_In_Billion_USD   61.0   709.889016  870.169692    39.23   102.72   296.04
# Per_Capita_in_USD    61.0   611.163934  618.757227    85.00   163.00   346.00
# Percentage_Growth    61.0     5.089344    3.282711    -6.60     3.74     5.71
#
#                         75%      max
# Year                2006.00  2021.00
# GDP_In_Billion_USD   940.26  3173.40
# Per_Capita_in_USD    807.00  2277.00
# Percentage_Growth      7.55     9.63

# %%
df.columns
# Out:
# Index(['Year', 'GDP_In_Billion_USD', 'Per_Capita_in_USD',
#        'Percentage_Growth '],
#       dtype='object')

# %% [markdown]
# So Here It's seen that overall the growth rate of India is increasing and negative rate is seen less number of time

# %%
plt.figure(figsize=(20,5))
plt.suptitle('HISTOGRAM',size=16,family='serif')

# Percentage Growth
plt.subplot(1,3,3)
plt.hist(df['Percentage_Growth '],color='green')
plt.title('Percentage Growth',color='green',size= 15,family='serif')

plt.show()

# %%
df.columns
# Out:
# Index(['Year', 'GDP_In_Billion_USD', 'Per_Capita_in_USD',
#        'Percentage_Growth '],
#       dtype='object')

# %%
# scatter plotting for 'GDP and Per Capita' vs 'Per_Capita_in_USD'

plt.figure(figsize=(14,4))
plt.scatter(df['GDP_In_Billion_USD'],df['Per_Capita_in_USD'],color='orange',marker='p')
plt.title("SCATTER PLOT",size=16,family='serif')
plt.xlabel('GDP_In_Billion_USD',size=15,color='blue')
plt.ylabel('Per Capita',size=15,color='blue')
plt.show()

# %%
# scatter plotting for 'GDP' vs 'Percentage growth'

plt.figure(figsize=(14,4))
plt.scatter(df['GDP_In_Billion_USD'],df['Percentage_Growth '],color='r',marker='p')
plt.title("SCATTER PLOT",size=16,family='serif')
plt.xlabel('GDP_In_Billion_USD',size=15,color='blue')
plt.ylabel('Percentage_Growth ',size=15,color='blue')
plt.show()
