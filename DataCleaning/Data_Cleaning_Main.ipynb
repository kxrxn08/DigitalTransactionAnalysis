# %%
import pandas as pd
df=pd.read_excel('MainData.xlsx',sheet_name=1)
df
# df.iloc[:,1:]
# Out:
#            Unnamed: 0                               PAYMENT TRANSACTIONS  \
# 0                 NaN                                       RBI Operated
# 1                 NaN                                               RTGS
# 2                Date                                                Vol
# 3      August 1, 2020                                                  h
# 4      August 2, 2020                                                  h
# 5      August 3, 2020                                            4.08792
# 6      August 4, 2020                                            5.50224
# 7      August 5, 2020                                            4.81097
# 8      August 6, 2020                                             4.9984
# 9      August 7, 2020                                            5.69707
# 10     August 8, 2020                                                  h
# 11     August 9, 2020                                                  h
# ...

# %%
import openpyxl
df=openpyxl.open('MainData.xlsx')

# %%
sheetnames=df.sheetnames
sheetnames
# Out:
# ['June 2020',
#  'August 2020',
#  'September 2020',
#  'October 2020',
#  'November 2020',
#  'April 2021',
#  'June 2021',
#  'July 2021',
#  'August 2021',
#  'September 2021',
#  'October 2021',
#  'November 2021',
#  'December 2021',
#  'January 2022 ',
#  'February 2022',
#  'March 2022',
#  'April 2022',
#  'May 2022',
#  'June 2022',
#  'July 2022',
#  'August 2022',
#  'September 2022',
#  'October 2022',
#  'November 2022',
#  'December 2022',
#  'January 2023',
#  'February 2023',
#  'March 2023',
#  'April 2023',
#  'May 2023',
#  'June 2023',
#  'July 2023']

# %%
# remvoe unnecessary sheets
selected_sheet=['June 2020','September 2020','November 2020','April 2021',
                'June 2021','September 2021','December 2021','March 2022','June 2022','September 2022','December 2022','March 2023','June 2023']
for i in sheetnames:
    if i not in selected_sheet:
        print(i)
        sheetnames.remove(i)
# Out:
# August 2021
# November 2021
# February 2022
# May 2022
# August 2022
# November 2022
# February 2023
# May 2023

# %%
sheetnames
# Out:
# ['June 2020',
#  'September 2020',
#  'November 2020',
#  'April 2021',
#  'June 2021',
#  'September 2021',
#  'December 2021',
#  'March 2022',
#  'June 2022',
#  'September 2022',
#  'December 2022',
#  'March 2023',
#  'June 2023']

# %%
df.worksheets[0]
print(df.worksheets[0])
# Out:
# <Worksheet "June 2020">

# %%
from openpyxl import load_workbook
workbook = load_workbook(filename='MainData.xlsx')
sheet_names = workbook.sheetnames
second_sheet = workbook[sheet_names[0]]
print(second_sheet)
second_sheet
# Out:
# <Worksheet "June 2020">
# <Worksheet "June 2020">

# %%
# l.append(v_df.head())
# v_dff=df.iloc[1,1:]
# l=['Date for the Day','Payment_RBI_RTGS_VOL','Payment_RBI_RTGS_VAL','Payment_RBI_NTFS_VOL','Payment_RBI_NTFS_VAL',
# 'Payment_NPCI_AePS_VOL','Payment_NPCI_AePS_VAL','Payment_NPCI_ UPI_VOL','Payment_NPCI_UPI_VAL','Payment_NPCI_IMPS_VOL','Payment_NPCI_IMPS_VAL',
# 'Payment_NPCI_NACH_Cr_VOL','Payment_NPCI_NACH_Cr_VAL','Payment_NPCI_NACH_Deb_VOL','Payment_NPCI_NACH_Deb_VAL','Payment_NPCI_NETC_VOL','Payment_NPCI_NETC_VAL',
# 'Payment_NPCI_BBPS_VOL','Payment_NPCI_BBPS_VAL','Payment_NPCI_CTS_VOL','Payment_NPCI_NPCI_Cr_VAL','Payment_CASH_NFS_VOL','Payment_CASH_NFS_VAL',
# 'Payment_CASH_AePS_VOL','Payment_CASH_AePS_VAL']
# v_df.columns=l
# v_df.drop(index=[0,1,2],inplace=True)
# v_df=v_df.reset_index(drop=True)
# for i in range(1,len(v_dff)):
    # print(v_dff[i])
    # if v_dff[i]==0:
    #     v_dff[i]=initial
    # else:
    #     initial=v_dff[i]
    # v_dff[i]=v_dff[i].replace("(","").replace(")","").replace("/","").strip().replace(" ","_")
    # v_dff[i]=v_dff.replace(" ","_")
# v_df.to_csv('demo.csv')
# v_df.head()

# %%
import pandas as pd
xlsx_file=pd.ExcelFile("MainData.xlsx")
s2=['January 2022 ',
 'February 2022',
 'March 2022',
 'April 2022',
 'May 2022',
 'June 2022',
 'July 2022',
 'August 2022',
 'September 2022',
 'October 2022',
 'November 2022',
 'December 2022',]
for i in range(0,len(s2)):
    v_df=pd.read_excel("MainData.xlsx",sheet_name=s2[i])
    csv_files=f'{s2[i]}_2022.csv'
    v_df.to_csv(csv_files,index=False)
# all_csv_into_one_file=[f'{sheetname}.csv' for sheetname in sheetnames]
# combined_df=pd.concat([pd.read_csv(csv_file) for csv_file in all_csv_into_one_file],ignore_index=True)
# combined_df.to_csv('combined_csv.csv',index=False)

# %%
import pandas as pd

v_df=pd.read_excel("MainData.xlsx",sheet_name="January 2022 ")
v_df.to_csv("January 2022_2022.csv",index=False)

# %%
df=pd.read_csv("MainData.xlsx - August 2020.csv")
dff=df.iloc[1,1:]
dff.fillna(0,inplace=True)
initial=dff[0]
for i in range(1,len(dff)):
    if dff[i]==0:
        dff[i]=initial
    else:
        initial=dff[i]   
    dff[i]=dff[i].replace("(","").replace(")","").replace("/",'').strip().replace("  ","_")
    dff[i]=dff[i].replace(" ","_")
dff
# Out:
# PAYMENT TRANSACTIONS                           RTGS
# Unnamed: 2                                     RTGS
# Unnamed: 3                                     NEFT
# Unnamed: 4                                     NEFT
# Unnamed: 5                                     AePS
# Unnamed: 6                                     AePS
# Unnamed: 7                                      UPI
# Unnamed: 8                                      UPI
# Unnamed: 9                                     IMPS
# Unnamed: 10                                    IMPS
# Unnamed: 11                             NACH_Credit
# Unnamed: 12                             NACH_Credit
# Unnamed: 13                              NACH_Debit
# Unnamed: 14                              NACH_Debit
# Unnamed: 15                                    NETC
# Unnamed: 16                                    NETC
# Unnamed: 17                                    BBPS
# Unnamed: 18                                    BBPS
# ...

# %%
import pandas as pd
df=pd.read_csv("June 2020.csv")
dff=df.iloc[1,1:]
dff.fillna(0,inplace=True)
initial=dff[0]
for i in range(1,len(dff)):
    if dff[i]==0:
        dff[i]=initial
    else:
        initial=dff[i]   
    dff[i]=dff[i].replace("(","").replace(")","").replace("/",'').strip().replace("  ","_")
    dff[i]=dff[i].replace(" ","_")
dff.fillna(0,inplace=True)
dff=df.iloc[0,1:]
dff
dff.fillna(0,inplace=True)
initial=dff[0]
for i in range(0,len(dff)):
    if dff[i]==0:
        dff[i]=initial
    else:
        initial=dff[i]   
    dff[i]=dff[i].replace("(","").replace(")","").replace("/",'').strip().replace("  ","_")
    dff[i]=dff[i].replace(" ","_")
df2=list(df.columns[1:])
initial=df.colum    ns[1]
print(df2)
type(df2)
for i in range(len(df2)):
    if "Unnamed:" in df2[i]:
        df2[i]=initial
    else:
        initial=df2[i]
df2
# Out:
# ['PAYMENT TRANSACTIONS', 'PAYMENT TRANSACTIONS.1', 'PAYMENT TRANSACTIONS.2', 'PAYMENT TRANSACTIONS.3', 'PAYMENT TRANSACTIONS.4', 'PAYMENT TRANSACTIONS.5', 'PAYMENT TRANSACTIONS.6', 'PAYMENT TRANSACTIONS.7', 'PAYMENT TRANSACTIONS.8', 'PAYMENT TRANSACTIONS.9', 'PAYMENT TRANSACTIONS.10', 'PAYMENT TRANSACTIONS.11', 'PAYMENT TRANSACTIONS.12', 'PAYMENT TRANSACTIONS.13', 'PAYMENT TRANSACTIONS.14', 'PAYMENT TRANSACTIONS.15', 'PAYMENT TRANSACTIONS.16', 'PAYMENT TRANSACTIONS.17', 'PAYMENT TRANSACTIONS.18', 'PAYMENT TRANSACTIONS.19', 'CASH WITHDRAWAL', 'CASH WITHDRAWAL.1', 'CASH WITHDRAWAL.2', 'CASH WITHDRAWAL.3']
# ['PAYMENT TRANSACTIONS',
#  'PAYMENT TRANSACTIONS.1',
#  'PAYMENT TRANSACTIONS.2',
#  'PAYMENT TRANSACTIONS.3',
#  'PAYMENT TRANSACTIONS.4',
#  'PAYMENT TRANSACTIONS.5',
#  'PAYMENT TRANSACTIONS.6',
#  'PAYMENT TRANSACTIONS.7',
#  'PAYMENT TRANSACTIONS.8',
#  'PAYMENT TRANSACTIONS.9',
#  'PAYMENT TRANSACTIONS.10',
#  'PAYMENT TRANSACTIONS.11',
#  'PAYMENT TRANSACTIONS.12',
# ...

# %%
dff.fillna(0,inplace=True)
dff
# Out:
# PAYMENT TRANSACTIONS                           RTGS
# Unnamed: 2                                     RTGS
# Unnamed: 3                                     NEFT
# Unnamed: 4                                     NEFT
# Unnamed: 5                                     AePS
# Unnamed: 6                                     AePS
# Unnamed: 7                                      UPI
# Unnamed: 8                                      UPI
# Unnamed: 9                                     IMPS
# Unnamed: 10                                    IMPS
# Unnamed: 11                             NACH_Credit
# Unnamed: 12                             NACH_Credit
# Unnamed: 13                              NACH_Debit
# Unnamed: 14                              NACH_Debit
# Unnamed: 15                                    NETC
# Unnamed: 16                                    NETC
# Unnamed: 17                                    BBPS
# Unnamed: 18                                    BBPS
# ...

# %%
dff=df.iloc[0,1:]
dff
dff.fillna(0,inplace=True)
initial=dff[0]
for i in range(0,len(dff)):
    if dff[i]==0:
        dff[i]=initial
    else:
        initial=dff[i]   
    dff[i]=dff[i].replace("(","").replace(")","").replace("/",'').strip().replace("  ","_")
    dff[i]=dff[i].replace(" ","_")
dff
# Out:
# PAYMENT TRANSACTIONS     RBI_Operated
# Unnamed: 2               RBI_Operated
# Unnamed: 3               RBI_Operated
# Unnamed: 4               RBI_Operated
# Unnamed: 5              NPCI_Operated
# Unnamed: 6              NPCI_Operated
# Unnamed: 7              NPCI_Operated
# Unnamed: 8              NPCI_Operated
# Unnamed: 9              NPCI_Operated
# Unnamed: 10             NPCI_Operated
# Unnamed: 11             NPCI_Operated
# Unnamed: 12             NPCI_Operated
# Unnamed: 13             NPCI_Operated
# Unnamed: 14             NPCI_Operated
# Unnamed: 15             NPCI_Operated
# Unnamed: 16             NPCI_Operated
# Unnamed: 17             NPCI_Operated
# Unnamed: 18             NPCI_Operated
# Unnamed: 19             NPCI_Operated
# Unnamed: 20             NPCI_Operated
# CASH WITHDRAWAL         NPCI_Operated
# Unnamed: 22             NPCI_Operated
# Unnamed: 23             NPCI_Operated
# Unnamed: 24             NPCI_Operated
# Name: 0, dtype: object

# %%
df2=list(df.columns[1:])
initial=df.columns[1]
type(df2)
# initial
# Out:
# list

# %%
# df2.replace(to_replace="Unnamed.*", value=0, regex=True, inplace=True)
for i in range(len(df2)):
    if "Unnamed:" in df2[i]:
        df2[i]=initial
    else:
        initial=df2[i]
df2
# Out:
# ['PAYMENT TRANSACTIONS',
#  'PAYMENT TRANSACTIONS',
#  'PAYMENT TRANSACTIONS',
#  'PAYMENT TRANSACTIONS',
#  'PAYMENT TRANSACTIONS',
#  'PAYMENT TRANSACTIONS',
#  'PAYMENT TRANSACTIONS',
#  'PAYMENT TRANSACTIONS',
#  'PAYMENT TRANSACTIONS',
#  'PAYMENT TRANSACTIONS',
#  'PAYMENT TRANSACTIONS',
#  'PAYMENT TRANSACTIONS',
#  'PAYMENT TRANSACTIONS',
#  'PAYMENT TRANSACTIONS',
#  'PAYMENT TRANSACTIONS',
#  'PAYMENT TRANSACTIONS',
#  'PAYMENT TRANSACTIONS',
#  'PAYMENT TRANSACTIONS',
#  'PAYMENT TRANSACTIONS',
#  'PAYMENT TRANSACTIONS',
#  'CASH WITHDRAWAL',
#  'CASH WITHDRAWAL',
#  'CASH WITHDRAWAL',
#  'CASH WITHDRAWAL']

# %%
df2.insert(0,0)
df2
# Out:
# [0,
#  'PAYMENT TRANSACTIONS',
#  'PAYMENT TRANSACTIONS',
#  'PAYMENT TRANSACTIONS',
#  'PAYMENT TRANSACTIONS',
#  'PAYMENT TRANSACTIONS',
#  'PAYMENT TRANSACTIONS',
#  'PAYMENT TRANSACTIONS',
#  'PAYMENT TRANSACTIONS',
#  'PAYMENT TRANSACTIONS',
#  'PAYMENT TRANSACTIONS',
#  'PAYMENT TRANSACTIONS',
#  'PAYMENT TRANSACTIONS',
#  'PAYMENT TRANSACTIONS',
#  'PAYMENT TRANSACTIONS',
#  'PAYMENT TRANSACTIONS',
#  'PAYMENT TRANSACTIONS',
#  'PAYMENT TRANSACTIONS',
#  'PAYMENT TRANSACTIONS',
#  'PAYMENT TRANSACTIONS',
#  'PAYMENT TRANSACTIONS',
#  'CASH WITHDRAWAL',
#  'CASH WITHDRAWAL',
#  'CASH WITHDRAWAL',
#  'CASH WITHDRAWAL']

# %%
df.columns=df2
df
# Out:
#                     0 PAYMENT TRANSACTIONS PAYMENT TRANSACTIONS  \
# 0                 NaN         RBI_Operated         RBI_Operated
# 1                 NaN                 RTGS                 RTGS
# 2                Date                  Vol                  Val
# 3      August 1, 2020                    h                    h
# 4      August 2, 2020                    h                    h
# 5      August 3, 2020                 4.09            319623.96
# 6      August 4, 2020                 5.50            285509.58
# 7      August 5, 2020                 4.81            322914.36
# 8      August 6, 2020                 5.00            336090.74
# 9      August 7, 2020                 5.70            316649.38
# 10     August 8, 2020                    h                    h
# 11     August 9, 2020                    h                    h
# 12    August 10, 2020                 7.03            428330.23
# 13    August 11, 2020                 4.76            284861.41
# ...

# %%
# l1=list(df.iloc[1:2,1:])
# l2=list(df.iloc[2:3,2:])
# l3=list(df.iloc[:,3:])
# l2
l1=df.iloc[0]
l1=list(l1)
l2=list(df.iloc[1])
l2.pop(0)
l1.pop(0)
len(l1)
len(l2)
l3=list(df.iloc[2])
l3.pop(0)
l3
l4=[]
for i,j,k in zip(l1,l2,l3):
    l4.append(i.replace(" ","_")+"_"+j.replace(" ","_")+"_"+k.replace(" ","_"))
l4
# Out:
# ['RBI_Operated_RTGS_Vol',
#  'RBI_Operated_RTGS_Val',
#  'RBI_Operated_NEFT_Vol',
#  'RBI_Operated_NEFT_Val',
#  'NPCI_Operated_AePS_Vol',
#  'NPCI_Operated_AePS_Val',
#  'NPCI_Operated_UPI_Vol',
#  'NPCI_Operated_UPI_Val',
#  'NPCI_Operated_IMPS_Vol',
#  'NPCI_Operated_IMPS_Val',
#  'NPCI_Operated_NACH_Credit_Vol',
#  'NPCI_Operated_NACH_Credit_Val',
#  'NPCI_Operated_NACH_Debit_Vol',
#  'NPCI_Operated_NACH_Debit_Val',
#  'NPCI_Operated_NETC_Vol',
#  'NPCI_Operated_NETC_Val',
#  'NPCI_Operated_BBPS_Vol',
#  'NPCI_Operated_BBPS_Val',
#  'NPCI_Operated_CTS_Vol',
#  'NPCI_Operated_CTS_Val',
#  'NPCI_Operated_NFS_through_ATMs_Vol',
#  'NPCI_Operated_NFS_through_ATMs_Val',
#  'NPCI_Operated_AePS_through_micro-ATMs_BCs_Vol',
#  'NPCI_Operated_AePS_through_micro-ATMs_BCs_Val']

# %%
l4.insert(0,'Date')
replacement_list = l4
len(replacement_list)
# Out:
# 26

# %%
df.columns=l4

# df.drop(index=range(0,3),inplace=True)

# l4.pop(1)

# %%
df.reset_index(drop=True, inplace=True)
df
# Out:
#                  Date                              RBI_Operated_RTGS_Vol  \
# 0      August 1, 2020                                                  h
# 1      August 2, 2020                                                  h
# 2      August 3, 2020                                               4.09
# 3      August 4, 2020                                               5.50
# 4      August 5, 2020                                               4.81
# 5      August 6, 2020                                               5.00
# 6      August 7, 2020                                               5.70
# 7      August 8, 2020                                                  h
# 8      August 9, 2020                                                  h
# 9     August 10, 2020                                               7.03
# 10    August 11, 2020                                               4.76
# 11    August 12, 2020                                               3.65
# ...

# %%
df.drop(index=43,inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\KARAN\Desktop\2.ipynb Cell 16 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/KARAN/Desktop/2.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> df.drop(index=43,inplace=True)
#       <a href='vscode-notebook-cell:/c%3A/Users/KARAN/Desktop/2.ipynb#X21sZmlsZQ%3D%3D?line=1'>2</a> df
#
# File c:\Users\KARAN\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
# save to csv
