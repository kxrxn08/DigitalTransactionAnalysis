# %%
import pandas as pd
import numpy as np

# %%
filename="May 2022_2022.csv"
df=pd.read_csv(filename)
dff=df.iloc[1,1:]
dff.fillna(0,inplace=True)
initial=dff[0]
for i in range(1,len(dff)):
    if dff[i]==0:
        dff[i]=initial
    else:
        initial=dff[i]   
    dff[i]=dff[i].replace("(","").replace(")","").replace("/",'').strip().replace("  ","_")
    dff[i]=dff[i].replace(" ","_")
dff
# Out:
# Payment and Settlement Systems – Daily Data Publication (updated as on June 01, 2022)                           RTGS
# Unnamed: 2                                                                                                      RTGS
# Unnamed: 3                                                                                                      NEFT
# Unnamed: 4                                                                                                      NEFT
# Unnamed: 5                                                                                                      AePS
# Unnamed: 6                                                                                                      AePS
# Unnamed: 7                                                                                                       UPI
# Unnamed: 8                                                                                                       UPI
# ...

# %%
dff.fillna(0,inplace=True)
dff
# Out:
# Payment and Settlement Systems – Daily Data Publication (updated as on June 01, 2022)                           RTGS
# Unnamed: 2                                                                                                      RTGS
# Unnamed: 3                                                                                                      NEFT
# Unnamed: 4                                                                                                      NEFT
# Unnamed: 5                                                                                                      AePS
# Unnamed: 6                                                                                                      AePS
# Unnamed: 7                                                                                                       UPI
# Unnamed: 8                                                                                                       UPI
# ...

# %%
dff=df.iloc[0,1:]
dff
dff.fillna(0,inplace=True)
initial=dff[0]
for i in range(0,len(dff)):
    if dff[i]==0:
        dff[i]=initial
    else:
        initial=dff[i]   
    dff[i]=dff[i].replace("(","").replace(")","").replace("/",'').strip().replace("  ","_")
    dff[i]=dff[i].replace(" ","_")
dff
# Out:
# Payment and Settlement Systems – Daily Data Publication (updated as on June 01, 2022)     RBI_Operated
# Unnamed: 2                                                                                RBI_Operated
# Unnamed: 3                                                                                RBI_Operated
# Unnamed: 4                                                                                RBI_Operated
# Unnamed: 5                                                                               NPCI_Operated
# Unnamed: 6                                                                               NPCI_Operated
# Unnamed: 7                                                                               NPCI_Operated
# Unnamed: 8                                                                               NPCI_Operated
# Unnamed: 9                                                                               NPCI_Operated
# ...

# %%
df2=list(df.columns[1:])
initial=df.columns[1]
type(df2)
# initial
# Out:
# list

# %%
# df2.replace(to_replace="Unnamed.*", value=0, regex=True, inplace=True)
for i in range(len(df2)):
    if "Unnamed:" in df2[i]:
        df2[i]=initial
    else:
        initial=df2[i]
df2
# Out:
# ['Payment and Settlement Systems – Daily Data Publication (updated as on June 01, 2022)',
#  'Payment and Settlement Systems – Daily Data Publication (updated as on June 01, 2022)',
#  'Payment and Settlement Systems – Daily Data Publication (updated as on June 01, 2022)',
#  'Payment and Settlement Systems – Daily Data Publication (updated as on June 01, 2022)',
#  'Payment and Settlement Systems – Daily Data Publication (updated as on June 01, 2022)',
#  'Payment and Settlement Systems – Daily Data Publication (updated as on June 01, 2022)',
#  'Payment and Settlement Systems – Daily Data Publication (updated as on June 01, 2022)',
#  'Payment and Settlement Systems – Daily Data Publication (updated as on June 01, 2022)',
#  'Payment and Settlement Systems – Daily Data Publication (updated as on June 01, 2022)',
#  'Payment and Settlement Systems – Daily Data Publication (updated as on June 01, 2022)',
# ...

# %%
df2.insert(0,0)
df2
# Out:
# [0,
#  'Payment and Settlement Systems – Daily Data Publication (updated as on June 01, 2022)',
#  'Payment and Settlement Systems – Daily Data Publication (updated as on June 01, 2022)',
#  'Payment and Settlement Systems – Daily Data Publication (updated as on June 01, 2022)',
#  'Payment and Settlement Systems – Daily Data Publication (updated as on June 01, 2022)',
#  'Payment and Settlement Systems – Daily Data Publication (updated as on June 01, 2022)',
#  'Payment and Settlement Systems – Daily Data Publication (updated as on June 01, 2022)',
#  'Payment and Settlement Systems – Daily Data Publication (updated as on June 01, 2022)',
#  'Payment and Settlement Systems – Daily Data Publication (updated as on June 01, 2022)',
#  'Payment and Settlement Systems – Daily Data Publication (updated as on June 01, 2022)',
#  'Payment and Settlement Systems – Daily Data Publication (updated as on June 01, 2022)',
# ...

# %%
df.columns=df2
df
# Out:
#                    0  \
# 0                NaN
# 1                NaN
# 2                NaN
# 3   01-05-2022 00:00
# 4   02-05-2022 00:00
# 5   03-05-2022 00:00
# 6   04-05-2022 00:00
# 7   05-05-2022 00:00
# 8   06-05-2022 00:00
# 9   07-05-2022 00:00
# 10  08-05-2022 00:00
# 11  09-05-2022 00:00
# 12  10-05-2022 00:00
# 13  11-05-2022 00:00
# 14  12-05-2022 00:00
# 15  13-05-2022 00:00
# 16  14-05-2022 00:00
# 17  15-05-2022 00:00
# 18  16-05-2022 00:00
# 19  17-05-2022 00:00
# 20  18-05-2022 00:00
# 21  19-05-2022 00:00
# 22  20-05-2022 00:00
# 23  21-05-2022 00:00
# 24  22-05-2022 00:00
# 25  23-05-2022 00:00
# 26  24-05-2022 00:00
# 27  25-05-2022 00:00
# 28  26-05-2022 00:00
# 29  27-05-2022 00:00
# 30  28-05-2022 00:00
# 31  29-05-2022 00:00
# 32  30-05-2022 00:00
# 33  31-05-2022 00:00
# 34    Total May 2022
# 35               NaN
# 36             Note:
# 37                 i
# 38                ii
# 39               iii
# 40                iv
# 41                 v
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 25 columns):
#  #   Column                                                                                 Non-Null Count  Dtype
# ---  ------                                                                                 --------------  -----
#  0   0                                                                                      43 non-null     object
#  1   Payment and Settlement Systems – Daily Data Publication (updated as on June 01, 2022)  45 non-null     object
#  2   Payment and Settlement Systems – Daily Data Publication (updated as on June 01, 2022)  35 non-null     object
#  3   Payment and Settlement Systems – Daily Data Publication (updated as on June 01, 2022)  35 non-null     object
#  4   Payment and Settlement Systems – Daily Data Publication (updated as on June 01, 2022)  35 non-null     object
# ...

# %%
l1=df.iloc[0]
l1=list(l1)
l2=list(df.iloc[1])
l2.pop(0)
l1.pop(0)
len(l1)
len(l2)
l3=list(df.iloc[2])
l3.pop(0)
l3
l4=[]
for i,j,k in zip(l1,l2,l3):
    l4.append(i.replace(" ","_")+"_"+j.replace(" ","_")+"_"+k.replace(" ","_"))
l4
# Out:
# ['RBI_Operated_RTGS_Vol',
#  'RBI_Operated_RTGS_Val',
#  'RBI_Operated_NEFT_Vol',
#  'RBI_Operated_NEFT_Val',
#  'NPCI_Operated_AePS_Vol',
#  'NPCI_Operated_AePS_Val',
#  'NPCI_Operated_UPI_Vol',
#  'NPCI_Operated_UPI_Val',
#  'NPCI_Operated_IMPS_Vol',
#  'NPCI_Operated_IMPS_Val',
#  'NPCI_Operated_NACH_Credit_Vol',
#  'NPCI_Operated_NACH_Credit_Val',
#  'NPCI_Operated_NACH_Debit_Vol',
#  'NPCI_Operated_NACH_Debit_Val',
#  'NPCI_Operated_NETC_Vol',
#  'NPCI_Operated_NETC_Val',
#  'NPCI_Operated_BBPS_Vol',
#  'NPCI_Operated_BBPS_Val',
#  'NPCI_Operated_CTS_Vol',
#  'NPCI_Operated_CTS_Val',
#  'NPCI_Operated_NFS_through_ATMs_Vol',
#  'NPCI_Operated_NFS_through_ATMs_Val',
#  'NPCI_Operated_AePS_through_micro-ATMs_BCs_Vol',
#  'NPCI_Operated_AePS_through_micro-ATMs_BCs_Val']

# %%
df.iloc[2]
# Out:
# 0                                                                                        NaN
# Payment and Settlement Systems – Daily Data Publication (updated as on June 01, 2022)    Vol
# Payment and Settlement Systems – Daily Data Publication (updated as on June 01, 2022)    Val
# Payment and Settlement Systems – Daily Data Publication (updated as on June 01, 2022)    Vol
# Payment and Settlement Systems – Daily Data Publication (updated as on June 01, 2022)    Val
# Payment and Settlement Systems – Daily Data Publication (updated as on June 01, 2022)    Vol
# Payment and Settlement Systems – Daily Data Publication (updated as on June 01, 2022)    Val
# Payment and Settlement Systems – Daily Data Publication (updated as on June 01, 2022)    Vol
# Payment and Settlement Systems – Daily Data Publication (updated as on June 01, 2022)    Val
# Payment and Settlement Systems – Daily Data Publication (updated as on June 01, 2022)    Vol
# ...

# %%
l4.insert(0,'Date')
replacement_list = l4
len(replacement_list)
# Out:
# 25

# %%
df.columns=l4

# df.drop(index=range(0,3),inplace=True)

# l4.pop(1)

# %%
df.reset_index(drop=True, inplace=True)
df
# Out:
#                 Date                              RBI_Operated_RTGS_Vol  \
# 0                NaN                                       RBI_Operated
# 1                NaN                                               RTGS
# 2                NaN                                                Vol
# 3   01-05-2022 00:00                                            0.59118
# 4   02-05-2022 00:00                                            8.30568
# 5   03-05-2022 00:00                                            1.57542
# 6   04-05-2022 00:00                                            9.48725
# 7   05-05-2022 00:00                                            8.29324
# 8   06-05-2022 00:00                                            8.43247
# 9   07-05-2022 00:00                                            6.74106
# 10  08-05-2022 00:00                                            0.57085
# 11  09-05-2022 00:00                                            8.53851
# ...

# %%
df.drop(index=range(0,3),inplace=True)
df
# Out:
#                 Date                              RBI_Operated_RTGS_Vol  \
# 3   01-05-2022 00:00                                            0.59118
# 4   02-05-2022 00:00                                            8.30568
# 5   03-05-2022 00:00                                            1.57542
# 6   04-05-2022 00:00                                            9.48725
# 7   05-05-2022 00:00                                            8.29324
# 8   06-05-2022 00:00                                            8.43247
# 9   07-05-2022 00:00                                            6.74106
# 10  08-05-2022 00:00                                            0.57085
# 11  09-05-2022 00:00                                            8.53851
# 12  10-05-2022 00:00                                            8.27664
# 13  11-05-2022 00:00                                            7.95476
# 14  12-05-2022 00:00                                            7.76258
# ...

# %%
df.reset_index(drop=True, inplace=True)
df
# Out:
#                 Date                              RBI_Operated_RTGS_Vol  \
# 0   01-05-2022 00:00                                            0.59118
# 1   02-05-2022 00:00                                            8.30568
# 2   03-05-2022 00:00                                            1.57542
# 3   04-05-2022 00:00                                            9.48725
# 4   05-05-2022 00:00                                            8.29324
# 5   06-05-2022 00:00                                            8.43247
# 6   07-05-2022 00:00                                            6.74106
# 7   08-05-2022 00:00                                            0.57085
# 8   09-05-2022 00:00                                            8.53851
# 9   10-05-2022 00:00                                            8.27664
# 10  11-05-2022 00:00                                            7.95476
# 11  12-05-2022 00:00                                            7.76258
# ...

# %%
df.to_csv(filename)

# %%
df2=pd.read_csv(filename)
df2.replace('h',0,inplace=True)
df2.to_csv(filename)

# %%
df3=pd.read_csv(filename)
df3
# Out:
#     Unnamed: 0.1  Unnamed: 0               Date  RBI_Operated_RTGS_Vol  \
# 0              0           0   November 1, 2020                0.00000
# 1              1           1   November 2, 2020                7.72716
# 2              2           2   November 3, 2020                6.41794
# 3              3           3   November 4, 2020                6.25696
# 4              4           4   November 5, 2020                6.07599
# 5              5           5   November 6, 2020                6.23207
# 6              6           6   November 7, 2020                5.27360
# 7              7           7   November 8, 2020                0.00000
# 8              8           8   November 9, 2020                7.14611
# 9              9           9  November 10, 2020                7.00933
# 10            10          10  November 11, 2020                7.00302
# 11            11          11  November 12, 2020                7.03758
# ...

# %%
import pandas as pd
total_df=pd.DataFrame()

# %%
sheetnames=['June 2020',
 'September 2020',
 'November 2020',
 'April 2021',
 'June 2021',
 'September 2021',
 'December 2021',
 'March 2022',
 'June 2022',
 'September 2022',
 'December 2022',
 'March 2023',
 'June 2023']
s2=['January 2022',
 'February 2022',
 'March 2022',
 'April 2022',
 'May 2022',
 'June 2022',
 'July 2022',
 'August 2022',
 'September 2022',
 'October 2022',
 'November 2022',
 'December 2022',]
l=[]
for i in s2:
    df=pd.read_csv(i+'_2022'+'.csv')
    last_row=df.tail(1)
    # df[last_row].rename=f'Total {i}'
    l=df.columns
    total_df=pd.concat([total_df,last_row],ignore_index=True)
total_df
# Out:
#                    Date  RBI_Operated_RTGS_Vol  RBI_Operated_RTGS_Val  \
# 0    Total January 2022              181.29052            10449109.50
# 1   Total February 2022              180.28552            10324617.82
# 2      Total March 2022              230.03813            14458955.04
# 3      Total April 2022              195.32430            11097594.49
# 4        Total May 2022              195.72062            11183946.97
# 5       Total June 2022              194.41531            12356053.53
# 6       Total July 2022              189.26270            11551439.68
# 7     Total August 2022              188.08020            11665582.71
# 8                 TOTAL              198.30016            13789637.12
# 9                 TOTAL              190.33650            11551276.86
# 10                TOTAL              206.45798            12291749.49
# 11                TOTAL              215.03150            13736057.18
#
# ...

# %%
indexes={"index":[]}
l=[]
for i in s2:
    indexName=f"Total {i}"
    indexes['index'].append(indexName)
indexes
total_df.index=indexes['index']
total_df.drop("Date",axis=1,inplace=True)
total_df
# Out:
#                       RBI_Operated_RTGS_Vol  RBI_Operated_RTGS_Val  \
# Total January 2022                181.29052            10449109.50
# Total February 2022               180.28552            10324617.82
# Total March 2022                  230.03813            14458955.04
# Total April 2022                  195.32430            11097594.49
# Total May 2022                    195.72062            11183946.97
# Total June 2022                   194.41531            12356053.53
# Total July 2022                   189.26270            11551439.68
# Total August 2022                 188.08020            11665582.71
# Total September 2022              198.30016            13789637.12
# Total October 2022                190.33650            11551276.86
# Total November 2022               206.45798            12291749.49
# Total December 2022               215.03150            13736057.18
#
#                       RBI_Operated_NEFT_Vol  RBI_Operated_NEFT_Val  \
# ...

# %%
total_df.to_csv("Total data of digital transactions_2022.csv")

# %%
total_df=pd.read_csv("Total data of digital transactions_2022.csv")
l=[]
total_df
# Out:
#               Unnamed: 0  RBI_Operated_RTGS_Vol  RBI_Operated_RTGS_Val  \
# 0     Total January 2022              181.29052            10449109.50
# 1    Total February 2022              180.28552            10324617.82
# 2       Total March 2022              230.03813            14458955.04
# 3       Total April 2022              195.32430            11097594.49
# 4         Total May 2022              195.72062            11183946.97
# 5        Total June 2022              194.41531            12356053.53
# 6        Total July 2022              189.26270            11551439.68
# 7      Total August 2022              188.08020            11665582.71
# 8   Total September 2022              198.30016            13789637.12
# 9     Total October 2022              190.33650            11551276.86
# 10   Total November 2022              206.45798            12291749.49
# 11   Total December 2022              215.03150            13736057.18
#
# ...

# %%
columns=list(total_df.columns)
columns.pop(0)
# Out:
# 'Unnamed: 0'

# %%
l=[np.nan]
for i in columns:
    l.append(total_df[i].sum())
l
# Out:
# [nan,
#  2358.68826,
#  153965400.195,
#  48475.25729000001,
#  34482272.459,
#  235.06972,
#  6585.468182299999,
#  628829.7283900001,
#  10758217.969500002,
#  51332.46214,
#  4930007.0992,
#  34639.45907,
#  1648826.6961500002,
#  12950.22257,
#  1239240.0944700001,
#  28126.79909,
#  45441.898865999996,
#  8233.32297,
#  146080.051528,
#  7749.3073,
#  7403936.821199999,
#  41972.833060000004,
#  1740907.5121,
#  11971.22947,
#  316937.92703]

# %%
l1,l2,l3,l4=[np.nan],[np.nan],[np.nan],[np.nan]
for i in range(13):
    print(total_df.iloc[i][0][-4:])
    if total_df.iloc[i][0][-4:]=='2020':
        l1.append(total_df.iloc[i,1:].sum())
    elif total_df.iloc[i][0][-4:]=='2021':
        l2.append(total_df.iloc[i,1:].sum())
    elif total_df.iloc[i][0][-4:]=='2022':
        l3.append(total_df.iloc[i,1:].sum())
    else:
        l4.append(total_df.iloc[i,1:].sum())
# Out:
# 2020
# 2020
# 2020
# 2021
# 2021
# 2021
# 2021
# 2022
# 2022
# 2022
# 2022
# 2023
# 2023

# %%
print(l1)
print(l2)
print(l3)
print(l4)
# Out:
# [nan, 11793167.960875398, 13049608.53378, 11752602.021372102]
# [nan, 12584498.078829998, 13987671.499510001, 15437740.655269999, 18020839.370800007]
# [nan, 20577266.88783, 17621813.907809995, 19376447.1713998, 19690031.501010004]
# [nan, 23165603.058201205, 20503437.9248678]

# %%
import pandas as pd
total_df=pd.read_csv("Total data of digital transactions.csv")
total_df
# Out:
#               Unnamed: 0  RBI_Operated_RTGS_Vol  RBI_Operated_RTGS_Val  \
# 0        Total June 2020              119.67608           8.651978e+06
# 1   Total September 2020              130.10503           9.489066e+06
# 2    Total November 2020              137.79836           7.987655e+06
# 3             Total 2020              387.57947           2.612870e+07
# 4       Total April 2021              151.52060           8.802868e+06
# 5        Total June 2021              154.13551           1.019699e+07
# 6   Total September 2021              174.56940           1.106963e+07
# 7    Total December 2021              192.78397           1.296699e+07
# 8             Total 2021              673.00948           4.303648e+07
# 9       Total March 2022              230.03813           1.445896e+07
# 10       Total June 2022              194.41531           1.235605e+07
# 11  Total September 2022              198.30016           1.378964e+07
# ...

# %%
# !pip install pygal
# Out:
# ...
# ERROR: Could not install packages due to an OSError: [Errno 13] Permission denied: 'c:\\Python311\\Scripts\\pygal_gen.py'
# Consider using the `--user` option or check the permissions.
#
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#                                               0.0/129.4 kB ? eta -:--:--
#      ---                                      10.2/129.4 kB ? eta -:--:--
#      ---                                      10.2/129.4 kB ? eta -:--:--
#      ---                                      10.2/129.4 kB ? eta -:--:--
#      ---                                      10.2/129.4 kB ? eta -:--:--
#      ---                                      10.2/129.4 kB ? eta -:--:--
#      ---                                      10.2/129.4 kB ? eta -:--:--
#      -----------------                     61.4/129.4 kB 233.8 kB/s eta 0:00:01
# ...

# %%
import matplotlib.pyplot as plt
import pygal
pie_chart = pygal.Pie(inner_radius=.4)
pie_chart.title = 'Browser usage in February 2012 (in %)'
pie_chart.add('IE', 19.5)
pie_chart.add('Firefox', 36.6)
pie_chart.add('Chrome', 36.3)
pie_chart.add('Safari', 4.5)
pie_chart.add('Opera', 2.3)
pie_chart.render_to_file("one.svg")
pie_chart.render()
# Out:
# b'<?xml version=\'1.0\' encoding=\'utf-8\'?>\n<svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="chart-0184fe89-a4d9-4a70-b1ca-1c650432b0de" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 3.0.0 (lxml) \xc2\xa9Kozea 2012-2016 on 2023-10-03--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-0184fe89-a4d9-4a70-b1ca-1c650432b0de{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-0184fe89-a4d9-4a70-b1ca-1c650432b0de .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-0184fe89-a4d9-4a70-b1ca-1c650432b0de .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-0184fe89-a4d9-4a70-b1ca-1c650432b0de .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-0184fe89-a4d9-4a70-b1ca-1c650432b
# ...

# %%
plt.pie([total_df.iloc[3,11],total_df.iloc[3,7]],labels=[total_df.iloc[3,0],total_df.iloc[3,0]],autopct="%.2f")
plt.show()

# %%
total_df.iloc[3,0]
# Out:
# 'Total 2020'

# %%
# Data Normalisation

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
df=pd.read_csv("Total data of digital transactions_2022.csv")
scalar=MinMaxScaler((0,5))
new_df=pd.DataFrame()
columns=list(df.columns)
columns.pop(0)
columns
for i in columns:
    normal=f'Normalised_{i}'
    df[normal]=scalar.fit_transform(df[[i]])
# df['Normalised_RTGS_Val']=scalar.fit_transform(df[['RBI_Operated_RTGS_Val']])

# new_df.to_csv("demo.csv")
df
# Out:
#               Unnamed: 0  RBI_Operated_RTGS_Vol  RBI_Operated_RTGS_Val  \
# 0     Total January 2022              181.29052            10449109.50
# 1    Total February 2022              180.28552            10324617.82
# 2       Total March 2022              230.03813            14458955.04
# 3       Total April 2022              195.32430            11097594.49
# 4         Total May 2022              195.72062            11183946.97
# 5        Total June 2022              194.41531            12356053.53
# 6        Total July 2022              189.26270            11551439.68
# 7      Total August 2022              188.08020            11665582.71
# 8   Total September 2022              198.30016            13789637.12
# 9     Total October 2022              190.33650            11551276.86
# 10   Total November 2022              206.45798            12291749.49
# 11   Total December 2022              215.03150            13736057.18
#
# ...

# %%
for i in columns:
    column_name=f'Normalised_{i}'
    new_df[column_name]=df[column_name]
# new_df.reset_index()
new_df['Total']=df['Unnamed: 0']
# new_df.reset_index(drop=True,inplace=True)
new_df.set_index('Total',inplace=True)
# new_df
new_df.to_csv("Normalised Total data of digital transaction 2022.csv")

# %%
import pandas as pd
new_df=pd.read_csv("Normalised Total data of digital transaction 2022.csv")
new_df
# Out:
#      Total  Normalised_RBI_Operated_RTGS_Vol  \
# 0   Jan-22                          0.101000
# 1   Feb-22                          0.000000
# 2   Mar-22                          5.000000
# 3   Apr-22                          1.511356
# 4   May-22                          1.551185
# 5   Jun-22                          1.420005
# 6   Jul-22                          0.902182
# 7   Aug-22                          0.783344
# 8   Sep-22                          1.810422
# 9   Oct-22                          1.010096
# 10  Nov-22                          2.630260
# 11  Dec-22                          3.491875
#
#     Normalised_RBI_Operated_RTGS_Val  Normalised_RBI_Operated_NEFT_Vol  \
# 0                           0.150558                          0.000000
# 1                           0.000000                          0.014482
# 2                           5.000000                          2.794833
# 3                           0.934825                          0.442827
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(2,1,figsize=(12,8))

# chart1
y1='Normalised_RBI_Operated_RTGS_Vol'
y2='Normalised_RBI_Operated_NEFT_Vol'
y3='Normalised_NPCI_Operated_UPI_Vol'
color = 'tab:red'
color2 = 'tab:blue'
color3='tab:green'
ax[0].set_title("RTGS vol vs UPI vol")
ax[0].set_xlabel('Total (s)')
ax[0].plot(new_df['Total'], new_df[y1], color=color,label=y1)
ax[0].tick_params(axis='y', labelcolor=color)
ax[0].plot(new_df['Total'], new_df[y3], color=color2,label=y3)
ax[0].tick_params(axis='y', labelcolor=color2)
# ax[0].plot(new_df['Total'], new_df[y3], color=color3,label=y3)
# ax[0].tick_params(axis='y', labelcolor=color3)
ax[0].legend(loc=9)
plt.tight_layout()
plt.show()

# %%
135688187-116712478
# Out:
# 18975709

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create some mock data
# t = np.arange(0.01, 10.0, 0.01)
# data1 = np.exp(t)
# data2 = np.sin(2 * np.pi * t)

fig, ax = plt.subplots()

color = 'tab:red'
ax.set_xlabel('Total (s)')
y1='Normalised_RBI_Operated_RTGS_Val'
y2='Normalised_RBI_Operated_RTGS_Vol'
y3='Normalised_RBI_Operated_NEFT_Vol'


# ax.set_ylabel(y1, color=color)
# ax1.plot(t,data1,color=color)
ax.plot(new_df['Total'], new_df[y1], color=color,label=y1)
ax.tick_params(axis='y', labelcolor=color)
ax.tick_params(axis='x', labelrotation=90)  # Set the rotation to 90 degrees


# ax2= ax.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:blue'
ax.plot(new_df['Total'], new_df[y2], color=color,label=y2)
ax.tick_params(axis='y', labelcolor=color)
# ax.set_ylabel(y2, color=color)



ax2 = ax.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:green'
y2='Normalised_RBI_Operated_RTGS_Vol'
ax2.plot(new_df['Total'], new_df[y3], color=color,label=y3)
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylabel(y3,color=color)



fig.tight_layout()  # otherwise the right y-label is slightly clipped
ax.legend(loc=0)
plt.show()

# %%
import pandas as pd
df=pd.read_csv("Total data of digital transactions_2022.csv")
s=df['RBI_Operated_RTGS_Vol'].sum()
s2=df['RBI_Operated_RTGS_Val'].sum()
s2/s
# Out:
# 61092.563556370944

# %%
neft_vol=df['RBI_Operated_NEFT_Vol'].sum()
neft_val=df['RBI_Operated_NEFT_Val'].sum()
neft_val/neft_vol
# Out:
# 662.79235054522

# %%
upi_vol=df['NPCI_Operated_UPI_Vol'].sum()
upi_val=df['NPCI_Operated_UPI_Val'].sum()
upi_val/upi_vol
# Out:
# 17.010462180717397

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(2,2,figsize=(12,8))
# plt.figure()
# Chart1
y1='Normalised_RBI_Operated_RTGS_Vol'
y2='Normalised_RBI_Operated_RTGS_Val'
color = 'tab:red'
color2 = 'tab:blue'
ax[0,0].set_title("RTGS Vol vs Val")
ax[0,0].set_xlabel('Total (s)')
ax[0,0].plot(new_df['Total'], new_df[y1], color=color,label=y1)
ax[0,0].tick_params(axis='y', labelcolor=color)
ax[0,0].tick_params(axis='x', labelrotation=45)  # Set the rotation to 90 degrees
# ax2=ax[0,0].twinx()
ax[0,0].plot(new_df['Total'], new_df[y2], color=color2,label=y2)
ax[0,0].tick_params(axis='y', labelcolor=color2)
ax[0,0].legend(loc=1)

# Chart2
y1='Normalised_RBI_Operated_NEFT_Vol'
y2='Normalised_RBI_Operated_NEFT_Val'
color = 'tab:red'
color2 = 'tab:blue'
ax[0,1].set_title("NEFT Vol vs Val")
ax[0,1].set_xlabel('Total (s)')
ax[0,1].plot(new_df['Total'], new_df[y1], color=color,label=y1)
ax[0,1].tick_params(axis='y', labelcolor=color)
ax[0,1].tick_params(axis='x', labelrotation=45)  # Set the rotation to 90 degrees
ax[0,1].plot(new_df['Total'], new_df[y2], color=color2,label=y2)
ax[0,1].tick_params(axis='y', labelcolor=color2)
ax[0,1].legend(loc=1)

# Chart3
y1='Normalised_NPCI_Operated_UPI_Vol'
y2='Normalised_NPCI_Operated_UPI_Val'
color = 'tab:red'
color2 = 'tab:blue'
ax[1,0].set_title("UPI Vol vs Val")
ax[1,0].set_xlabel('Total (s)')
ax[1,0].plot(new_df['Total'], new_df[y1], color=color,label=y1)
ax[1,0].tick_params(axis='y', labelcolor=color)
ax[1,0].tick_params(axis='x', labelrotation=45)  # Set the rotation to 90 degrees
ax[1,0].plot(new_df['Total'], new_df[y2], color=color2,label=y2)
ax[1,0].tick_params(axis='y', labelcolor=color2)
ax[1,0].legend(loc=0)

# Chart4
y1='Normalised_NPCI_Operated_IMPS_Vol'
y2='Normalised_NPCI_Operated_IMPS_Val'
color = 'tab:red'
color2 = 'tab:blue'
ax[1,1].set_title("IMPS Vol vs Val")
ax[1,1].set_xlabel('Total (s)')
ax[1,1].plot(new_df['Total'], new_df[y1], color=color,label=y1)
ax[1,1].tick_params(axis='y', labelcolor=color)
ax[1,1].tick_params(axis='x', labelrotation=45)  # Set the rotation to 90 degrees
ax[1,1].plot(new_df['Total'], new_df[y2], color=color2,label=y2)
ax[1,1].tick_params(axis='y', labelcolor=color2)
ax[1,1].legend(loc=0)


fig.tight_layout()  
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(2,1,figsize=(12,8))

# chart1
y1='Normalised_RBI_Operated_RTGS_Vol'
y2='Normalised_RBI_Operated_NEFT_Vol'
y3='Normalised_NPCI_Operated_UPI_Vol'
color = 'tab:red'
color2 = 'tab:blue'
color3='tab:green'
ax[0].set_title("RTGS vol vs NEFT vol vs UPI vol")
ax[0].set_xlabel('Total (s)')
ax[0].plot(new_df['Total'], new_df[y1], color=color,label=y1)
ax[0].tick_params(axis='y', labelcolor=color)
ax[0].plot(new_df['Total'], new_df[y2], color=color2,label=y2)
ax[0].tick_params(axis='y', labelcolor=color2)
ax[0].plot(new_df['Total'], new_df[y3], color=color3,label=y3)
ax[0].tick_params(axis='y', labelcolor=color3)
ax[0].legend(loc=9)


# chart2
y1='Normalised_RBI_Operated_RTGS_Val'
y2='Normalised_RBI_Operated_NEFT_Val'
y3='Normalised_NPCI_Operated_UPI_Val'
color = 'tab:red'
color2 = 'tab:blue'
color3='tab:green'
ax[1].set_title("RTGS val vs NEFT val vs UPI val")
ax[1].set_xlabel('Total (s)')
ax[1].plot(new_df['Total'], new_df[y1], color=color,label=y1)
ax[1].tick_params(axis='y', labelcolor=color)
ax[1].plot(new_df['Total'], new_df[y2], color=color2,label=y2)
ax[1].tick_params(axis='y', labelcolor=color2)
ax[1].plot(new_df['Total'], new_df[y3], color=color3,label=y3)
ax[1].tick_params(axis='y', labelcolor=color3)
ax[1].legend(loc=9)
fig.tight_layout()
plt.show()
