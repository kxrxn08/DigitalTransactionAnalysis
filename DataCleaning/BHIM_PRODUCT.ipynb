# %%
import pandas as pd
import numpy as np

# %% [markdown]
# In this notebook we have shown the number of Banks live and giving the digital transaction services to the customer

# %% [markdown]
# <h2>Read the csv file </h2>

# %%
bhim=pd.read_csv('BHIM_PRODUCT_ANAYSIS_TILL_DATE.csv')
bhim
# Out:
#           Month No_of_Banks_live_on_BHIM Volume_in_Mn Value_in_Cr
# 0      Aug-2023                      360        24.32     7742.34
# 1      Jul-2023                      282        24.66     8201.86
# 2      Jun-2023                      282         22.9     7258.64
# 3      May-2023                      280         22.8     7189.16
# 4    April-2023                      277        23.61     7349.81
# ..          ...                      ...          ...         ...
# 84  August-2016                        -            -           -
# 85    July-2016                        -            -           -
# 86    June-2016                        -            -           -
# 87     May-2016                        -            -           -
# 88   April-2016                        -            -           -
#
# [89 rows x 4 columns]

# %%
bhim.tail(10)
# Out:
#              Month No_of_Banks_live_on_BHIM Volume_in_Mn Value_in_Cr
# 79    January-2017                       35         1.72       356.5
# 80   December-2016                       31         0.04        1.85
# 81   November-2016                        -            -           -
# 82    October-2016                        -            -           -
# 83  September-2016                        -            -           -
# 84     August-2016                        -            -           -
# 85       July-2016                        -            -           -
# 86       June-2016                        -            -           -
# 87        May-2016                        -            -           -
# 88      April-2016                        -            -           -

# %%
# no available data
bhim.drop(index=range(81,89),inplace=True)

# %%
xLabel=bhim[['Month']]
xLabel
# Out:
#             Month
# 0        Aug-2023
# 1        Jul-2023
# 2        Jun-2023
# 3        May-2023
# 4      April-2023
# ..            ...
# 76     April-2017
# 77     March-2017
# 78  February-2017
# 79   January-2017
# 80  December-2016
#
# [81 rows x 1 columns]

# %%
bhim.dtypes
# Out:
# Month                       object
# No_of_Banks_live_on_BHIM    object
# Volume_in_Mn                object
# Value_in_Cr                 object
# dtype: object

# %%
import matplotlib.pyplot as plt
# plt.plot(bhim[['No_of_Banks_live_on_BHIM']])
# plt.show()
bhim['No_of_Banks_live_on_BHIM']=bhim['No_of_Banks_live_on_BHIM'].astype(np.int64)
bhim['Volume_in_Mn']=bhim['Volume_in_Mn'].astype(np.float64)
bhim['Value_in_Cr']=bhim['Value_in_Cr'].astype(np.float64)
reversedB=bhim['No_of_Banks_live_on_BHIM'][::-1]
reversedB
# Out:
# 80     31
# 79     35
# 78     44
# 77     44
# 76     44
#      ...
# 4     277
# 3     280
# 2     282
# 1     282
# 0     360
# Name: No_of_Banks_live_on_BHIM, Length: 81, dtype: int64

# %% [markdown]
# <h1>Visulisation of the BHIM Data</h1>

# %% [markdown]
# Overall the no. of banks is seen increasing on year to year basis thus this shows the active participation of private sectors in these area

# %%
# plt.figure(figsize=(20, 10))
# plt.bar(x=bhim['Month'],height=bhim['No_of_Banks_live_on_BHIM'])
# plt.xticks(rotation=90)


import matplotlib.pyplot as plt

plt.figure(figsize=(10, 20))
plt.barh(y=bhim['Month'], width=bhim['No_of_Banks_live_on_BHIM'])

# plt.xlabel('Number of Banks on BHIM')
plt.title('Horizontal Bar Graph with Vertical X-Labels')
# plt.xticks(rotation=90)

plt.show()

# %%
x=bhim['Month'][::-1]
y=bhim['No_of_Banks_live_on_BHIM'][::-1]
y
y2=bhim['Volume_in_Mn'][::-1]
y3=bhim['Value_in_Cr'][::-1]*0.01

# %% [markdown]
# There is a step increase seen in the current year

# %%
plt.figure(figsize=(30,10))
plt.plot(x,y)
# plt.plot(x,y2)
# plt.plot(x,y3)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# During the starting year when people seems it new technology thus the transaction amount has step increase but after this the rate between the two seems to have stablize

# %%
plt.figure(figsize=(30,10))
plt.plot(x,y2)
plt.plot(x,y3)
plt.xticks(rotation="vertical")
plt.legend(["volume in millions","value in crores, divided by 100 for scaling"])
# plt.legend(["value in crores divided by 1000 for scaling"])
