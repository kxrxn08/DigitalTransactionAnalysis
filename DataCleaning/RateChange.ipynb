# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("./Total data of digital transactions_2022.csv")
df.head()
# Out:
#             Unnamed: 0  RBI_Operated_RTGS_Vol  RBI_Operated_RTGS_Val  \
# 0   Total January 2022              181.29052            10449109.50
# 1  Total February 2022              180.28552            10324617.82
# 2     Total March 2022              230.03813            14458955.04
# 3     Total April 2022              195.32430            11097594.49
# 4       Total May 2022              195.72062            11183946.97
#
#    RBI_Operated_NEFT_Vol  RBI_Operated_NEFT_Val  NPCI_Operated_AePS_Vol  \
# 0             3629.02969            2442685.818                   25.02
# 1             3632.57994            2477058.565                   15.74
# 2             4314.20070            3492578.209                   20.03
# 3             3737.59155            2498586.903                   17.31
# 4             3813.34486            2546927.612                   18.39
#
#    NPCI_Operated_AePS_Val  NPCI_Operated_UPI_Vol  NPCI_Operated_UPI_Val  \
# ...

# %%
RTGS=df[["Unnamed: 0","RBI_Operated_RTGS_Vol","RBI_Operated_RTGS_Val"]]
RTGS
# Out:
#               Unnamed: 0  RBI_Operated_RTGS_Vol  RBI_Operated_RTGS_Val
# 0     Total January 2022              181.29052           1.044911e+07
# 1    Total February 2022              180.28552           1.032462e+07
# 2       Total March 2022              230.03813           1.445896e+07
# 3       Total April 2022              195.32430           1.109759e+07
# 4         Total May 2022              195.72062           1.118395e+07
# 5        Total June 2022              194.41531           1.235605e+07
# 6        Total July 2022              189.26270           1.155144e+07
# 7      Total August 2022              188.08020           1.166558e+07
# 8   Total September 2022              198.30016           1.378964e+07
# 9     Total October 2022              190.33650           1.155128e+07
# 10   Total November 2022              206.45798           1.229175e+07
# 11   Total December 2022              215.03150           1.373606e+07
# ...

# %%
RTGS['Rate_of_Increase_Vol'] = df['RBI_Operated_RTGS_Vol'].diff()
RTGS['Rate_of_Increase_Val'] = df['RBI_Operated_RTGS_Val'].diff()
RTGS
# Out:
# C:\Users\Viren\AppData\Local\Temp\ipykernel_18416\3748355550.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RTGS['Rate_of_Increase_Vol'] = df['RBI_Operated_RTGS_Vol'].diff()
# C:\Users\Viren\AppData\Local\Temp\ipykernel_18416\3748355550.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RTGS['Rate_of_Increase_Val'] = df['RBI_Operated_RTGS_Val'].diff()
#               Unnamed: 0  RBI_Operated_RTGS_Vol  RBI_Operated_RTGS_Val  \
# ...

# %%
RTGS.dropna(inplace=True)
RTGS.drop(index=12,inplace=True)
RTGS
# Out:
# C:\Users\Viren\AppData\Local\Temp\ipykernel_18416\3528101527.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RTGS.dropna(inplace=True)
# C:\Users\Viren\AppData\Local\Temp\ipykernel_18416\3528101527.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RTGS.drop(index=12,inplace=True)
#               Unnamed: 0  RBI_Operated_RTGS_Vol  RBI_Operated_RTGS_Val  \
# 1    Total February 2022              180.28552            10324617.82
# 2       Total March 2022              230.03813            14458955.04
# 3       Total April 2022              195.32430            11097594.49
# ...

# %%
plt.figure(figsize=(10, 6))
plt.plot(RTGS['Unnamed: 0'], RTGS['Rate_of_Increase_Vol'], marker='o', linestyle='-')
plt.title('RTGS: Rate of Increaseof Volume Over Time')
plt.xlabel('Months')
plt.ylabel('Rate of Increase')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(RTGS['Unnamed: 0'], RTGS['Rate_of_Increase_Val'], marker='o', linestyle='-')
plt.title('RTGS: Rate of Increaseof Value Over Time')
plt.xlabel('Months')
plt.ylabel('Rate of Increase')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
df.head()
# Out:
#             Unnamed: 0  RBI_Operated_RTGS_Vol  RBI_Operated_RTGS_Val  \
# 0   Total January 2022              181.29052            10449109.50
# 1  Total February 2022              180.28552            10324617.82
# 2     Total March 2022              230.03813            14458955.04
# 3     Total April 2022              195.32430            11097594.49
# 4       Total May 2022              195.72062            11183946.97
#
#    RBI_Operated_NEFT_Vol  RBI_Operated_NEFT_Val  NPCI_Operated_AePS_Vol  \
# 0             3629.02969            2442685.818                   25.02
# 1             3632.57994            2477058.565                   15.74
# 2             4314.20070            3492578.209                   20.03
# 3             3737.59155            2498586.903                   17.31
# 4             3813.34486            2546927.612                   18.39
#
#    NPCI_Operated_AePS_Val  NPCI_Operated_UPI_Vol  NPCI_Operated_UPI_Val  \
# ...

# %%
NEFT=df[["Unnamed: 0","RBI_Operated_NEFT_Vol","RBI_Operated_NEFT_Val"]]
NEFT
# Out:
#               Unnamed: 0  RBI_Operated_NEFT_Vol  RBI_Operated_NEFT_Val
# 0     Total January 2022             3629.02969           2.442686e+06
# 1    Total February 2022             3632.57994           2.477059e+06
# 2       Total March 2022             4314.20070           3.492578e+06
# 3       Total April 2022             3737.59155           2.498587e+06
# 4         Total May 2022             3813.34486           2.546928e+06
# 5        Total June 2022             4022.32850           2.716013e+06
# 6        Total July 2022             4018.39279           2.627354e+06
# 7      Total August 2022             4166.75667           2.631639e+06
# 8   Total September 2022             4332.45421           2.922913e+06
# 9     Total October 2022             4570.47514           2.726827e+06
# 10   Total November 2022             4388.30132           2.730878e+06
# 11   Total December 2022             4854.81151           2.981681e+06
# ...

# %%
NEFT['Rate_of_Increase_Vol'] = df['RBI_Operated_NEFT_Vol'].diff()
NEFT['Rate_of_Increase_Val'] = df['RBI_Operated_NEFT_Val'].diff()
NEFT
# Out:
# C:\Users\Viren\AppData\Local\Temp\ipykernel_18416\3176027583.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NEFT['Rate_of_Increase_Vol'] = df['RBI_Operated_NEFT_Vol'].diff()
# C:\Users\Viren\AppData\Local\Temp\ipykernel_18416\3176027583.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NEFT['Rate_of_Increase_Val'] = df['RBI_Operated_NEFT_Val'].diff()
#               Unnamed: 0  RBI_Operated_NEFT_Vol  RBI_Operated_NEFT_Val  \
# ...

# %%
NEFT.dropna(inplace=True)
NEFT.drop(index=12,inplace=True)
NEFT
# Out:
# C:\Users\Viren\AppData\Local\Temp\ipykernel_18416\628078538.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NEFT.dropna(inplace=True)
# C:\Users\Viren\AppData\Local\Temp\ipykernel_18416\628078538.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NEFT.drop(index=12,inplace=True)
#               Unnamed: 0  RBI_Operated_NEFT_Vol  RBI_Operated_NEFT_Val  \
# 1    Total February 2022             3632.57994            2477058.565
# 2       Total March 2022             4314.20070            3492578.209
# 3       Total April 2022             3737.59155            2498586.903
# ...

# %%
plt.figure(figsize=(10, 6))
plt.plot(NEFT['Unnamed: 0'], NEFT['Rate_of_Increase_Vol'], marker='o', linestyle='-')
plt.title('NEFT: Rate of Increase of Volume Over Time')
plt.xlabel('Months')
plt.ylabel('Rate of Increase')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(NEFT['Unnamed: 0'], NEFT['Rate_of_Increase_Val'], marker='o', linestyle='-')
plt.title('NEFT: Rate of Increaseof Value Over Time')
plt.xlabel('Months')
plt.ylabel('Rate of Increase')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
RTGS = {'Year': ['2017-18', '2018-19', '2019-20'],
        'Volume (Lakh)': [1244,1366,1507],
        'Value (Crore)':[116712478,135688187,131156475]}

RTGS = pd.DataFrame(RTGS)
RTGS
# Out:
#       Year  Volume (Lakh)  Value (Crore)
# 0  2017-18           1244      116712478
# 1  2018-19           1366      135688187
# 2  2019-20           1507      131156475

# %%
RTGS['Rate_of_Increase_Vol'] = RTGS['Volume (Lakh)'].diff()
RTGS['Rate_of_Increase_Val'] = RTGS['Value (Crore)'].diff()
RTGS
# Out:
#       Year  Volume (Lakh)  Value (Crore)  Rate_of_Increase_Vol  \
# 0  2017-18           1244      116712478                   NaN
# 1  2018-19           1366      135688187                 122.0
# 2  2019-20           1507      131156475                 141.0
#
#    Rate_of_Increase_Val
# 0                   NaN
# 1            18975709.0
# 2            -4531712.0

# %%
plt.figure(figsize=(10, 6))
plt.plot(RTGS['Year'], RTGS['Volume (Lakh)'], marker='o', linestyle='-')
plt.title('RTGS: Rate of Increaseof Volume Over Time')
plt.xlabel('Year')
plt.ylabel('Rate of Increase')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
RTGS.dropna(inplace=True)
RTGS
# Out:
#       Year  Volume (Lakh)  Value (Crore)  Rate_of_Increase_Vol  \
# 1  2018-19           1366      135688187                 122.0
# 2  2019-20           1507      131156475                 141.0
#
#    Rate_of_Increase_Val
# 1            18975709.0
# 2            -4531712.0

# %%
plt.figure(figsize=(10, 6))
plt.plot(RTGS['Year'], RTGS['Rate_of_Increase_Vol'], marker='o', linestyle='-')
plt.title('RTGS: Rate of Increaseof Volume Over Time')
plt.xlabel('Year')
plt.ylabel('Rate of Increase')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
NEFT = {'Year': ['2017-18', '2018-19', '2019-20'],
        'Volume (Lakh)': [19464,23189,27445],
        'Value (Crore)':[17222852,22793608,22945580]}

NEFT = pd.DataFrame(NEFT)
NEFT
# Out:
#       Year  Volume (Lakh)  Value (Crore)
# 0  2017-18          19464       17222852
# 1  2018-19          23189       22793608
# 2  2019-20          27445       22945580

# %%
NEFT['Rate_of_Increase_Vol'] = NEFT['Volume (Lakh)'].diff()
NEFT['Rate_of_Increase_Val'] = NEFT['Value (Crore)'].diff()
NEFT
# Out:
#       Year  Volume (Lakh)  Value (Crore)  Rate_of_Increase_Vol  \
# 0  2017-18          19464       17222852                   NaN
# 1  2018-19          23189       22793608                3725.0
# 2  2019-20          27445       22945580                4256.0
#
#    Rate_of_Increase_Val
# 0                   NaN
# 1             5570756.0
# 2              151972.0

# %%
plt.figure(figsize=(10, 6))
plt.plot(NEFT['Year'], NEFT['Volume (Lakh)'], marker='o', linestyle='-')
plt.title('RTGS: Rate of Increaseof Volume Over Time')
plt.xlabel('Year')
plt.ylabel('Rate of Increase')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
NEFT.dropna(inplace=True)
NEFT
# Out:
#       Year  Volume (Lakh)  Value (Crore)  Rate_of_Increase_Vol  \
# 1  2018-19          23189       22793608                3725.0
# 2  2019-20          27445       22945580                4256.0
#
#    Rate_of_Increase_Val
# 1             5570756.0
# 2              151972.0

# %%
plt.figure(figsize=(10, 6))
plt.plot(NEFT['Year'], NEFT['Rate_of_Increase_Vol'], marker='o', linestyle='-')
plt.title('RTGS: Rate of Increaseof Volume Over Time')
plt.xlabel('Year')
plt.ylabel('Rate of Increase')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()
